# %%
import os
import shutil
from PIL import Image
from tqdm import tqdm

# %%
# 📂 Original dataset location
original_datasets = {
    "plantdoc": r"C:\Users\tiwar\plant_disease_detection\Dataset\plantdoc",
    "agri_india": r"C:\Users\tiwar\plant_disease_detection\Dataset\agri_india",
    "wheat_disease": r"C:\Users\tiwar\plant_disease_detection\Dataset\wheat_disease"
}

# 📂 Final cleaned dataset location
processed_path = r"C:\Users\tiwar\plant_disease_detection\processed_dataset"

# 📏 Set standard image size for all inputs (used in DL models)
standard_size = (224, 224)

# %%
def clean_and_resize_images(source_path, target_path, size=(224, 224)):
    """
    Clean, resize and copy images from source to target path.
    Skips corrupted images.
    """
    total_images = 0
    corrupted_count = 0

    for class_folder in os.listdir(source_path):
        class_path = os.path.join(source_path, class_folder)
        if not os.path.isdir(class_path):
            continue

        # Create same class folder in target
        target_class_path = os.path.join(target_path, class_folder)
        os.makedirs(target_class_path, exist_ok=True)

        # Process images in each class
        for img_file in tqdm(os.listdir(class_path), desc=f"📁 Processing {class_folder}"):
            src_img_path = os.path.join(class_path, img_file)
            try:
                with Image.open(src_img_path) as img:
                    img = img.convert("RGB")
                    img = img.resize(size)
                    
                    # Uniform name (no spaces, no special chars)
                    clean_name = f"{class_folder.replace(' ', '_')}_{total_images}.jpg"
                    save_path = os.path.join(target_class_path, clean_name)
                    img.save(save_path)
                    total_images += 1

            except Exception as e:
                corrupted_count += 1
                continue

    print(f"\n✅ Done: {total_images} images saved.")
    print(f"⚠️ Corrupted/Skipped: {corrupted_count}")

# %%
# Make sure final target folder exists
os.makedirs(processed_path, exist_ok=True)

# Loop through and process each dataset
for name, path in original_datasets.items():
    print(f"\n🔄 Processing Dataset: {name}")
    clean_and_resize_images(path, processed_path)
# Out:
# 🔄 Processing Dataset: plantdoc
# 📁 Processing Apple_leaf: 100%|████████████████████████████████████████████████████████| 88/88 [00:04<00:00, 18.46it/s]
# 📁 Processing Apple_rust_leaf: 100%|█████████████████████████████████████████████████| 106/106 [00:05<00:00, 20.70it/s]
# 📁 Processing Apple_Scab_Leaf: 100%|███████████████████████████████████████████████████| 93/93 [00:03<00:00, 26.73it/s]
# 📁 Processing Bell_pepper_leaf: 100%|██████████████████████████████████████████████████| 42/42 [00:01<00:00, 27.03it/s]
# 📁 Processing Bell_pepper_leaf_spot: 100%|█████████████████████████████████████████████| 83/83 [00:04<00:00, 18.02it/s]
# 📁 Processing Blueberry_leaf: 100%|██████████████████████████████████████████████████| 117/117 [00:06<00:00, 17.71it/s]
# 📁 Processing Cherry_leaf: 100%|███████████████████████████████████████████████████████| 57/57 [00:04<00:00, 13.83it/s]
# 📁 Processing Corn_Gray_leaf_spot: 100%|███████████████████████████████████████████████| 67/67 [00:02<00:00, 25.93it/s]
# 📁 Processing Corn_leaf_blight: 100%|████████████████████████████████████████████████| 194/194 [00:09<00:00, 20.86it/s]
# 📁 Processing Corn_rust_leaf: 100%|██████████████████████████████████████████████████| 117/117 [00:06<00:00, 18.04it/s]
# 📁 Processing grape_leaf: 100%|████████████████████████████████████████████████████████| 75/75 [00:08<00:00,  8.69it/s]
# 📁 Processing grape_leaf_black_rot: 100%|██████████████████████████████████████████████| 79/79 [00:04<00:00, 19.63it/s]
# 📁 Processing Peach_leaf: 100%|██████████████████████████████████████████████████████| 112/112 [00:06<00:00, 18.35it/s]
# 📁 Processing Potato_leaf_early_blight: 100%|████████████████████████████████████████| 171/171 [00:05<00:00, 28.96it/s]
# 📁 Processing Potato_leaf_late_blight: 100%|█████████████████████████████████████████| 208/208 [00:07<00:00, 29.41it/s]
# 📁 Processing Raspberry_leaf: 100%|██████████████████████████████████████████████████| 119/119 [00:06<00:00, 18.83it/s]
# 📁 Processing Soyabean_leaf: 100%|█████████████████████████████████████████████████████| 65/65 [00:05<00:00, 12.93it/s]
# 📁 Processing Squash_Powdery_mildew_leaf: 100%|██████████████████████████████████████| 130/130 [00:07<00:00, 17.99it/s]
# 📁 Processing Strawberry_leaf: 100%|███████████████████████████████████████████████████| 96/96 [00:06<00:00, 14.63it/s]
# 📁 Processing Tomato_Early_blight_leaf: 100%|██████████████████████████████████████████| 88/88 [00:03<00:00, 26.99it/s]
# 📁 Processing Tomato_leaf: 100%|███████████████████████████████████████████████████████| 52/52 [00:03<00:00, 14.86it/s]
# 📁 Processing Tomato_leaf_bacterial_spot: 100%|██████████████████████████████████████| 110/110 [00:03<00:00, 28.94it/s]
# 📁 Processing Tomato_leaf_late_blight: 100%|█████████████████████████████████████████| 111/111 [00:05<00:00, 18.99it/s]
# 📁 Processing Tomato_leaf_mosaic_virus: 100%|██████████████████████████████████████████| 54/54 [00:01<00:00, 32.05it/s]
# 📁 Processing Tomato_leaf_yellow_virus: 100%|████████████████████████████████████████| 238/238 [00:05<00:00, 41.30it/s]
# 📁 Processing Tomato_mold_leaf: 100%|██████████████████████████████████████████████████| 91/91 [00:04<00:00, 21.53it/s]
# 📁 Processing Tomato_Septoria_leaf_spot: 100%|███████████████████████████████████████| 157/157 [00:07<00:00, 21.88it/s]
# 📁 Processing Tomato_two_spotted_spider_mites_leaf: 100%|████████████████████████████████| 2/2 [00:00<00:00, 42.21it/s]
# ✅ Done: 2922 images saved.
# ⚠️ Corrupted/Skipped: 0
#
# 🔄 Processing Dataset: agri_india
# 📁 Processing American Bollworm on Cotton: 100%|███████████████████████████████████████| 56/56 [00:03<00:00, 17.17it/s]
# 📁 Processing Anthracnose on Cotton: 100%|█████████████████████████████████████████████| 29/29 [00:01<00:00, 16.07it/s]
# 📁 Processing Army worm: 100%|█████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 40.30it/s]
# 📁 Processing bacterial_blight in Cotton: 100%|██████████████████████████████████████| 489/489 [00:11<00:00, 41.00it/s]
# 📁 Processing Becterial Blight in Rice: 100%|██████████████████████████████████████| 1584/1584 [00:26<00:00, 60.41it/s]
# 📁 Processing bollrot on Cotton: 100%|███████████████████████████████████████████████████| 2/2 [00:00<00:00, 53.64it/s]
# 📁 Processing bollworm on Cotton: 100%|████████████████████████████████████████████████| 22/22 [00:00<00:00, 25.56it/s]
# 📁 Processing Brownspot: 100%|█████████████████████████████████████████████████████| 1640/1640 [00:24<00:00, 66.25it/s]
# 📁 Processing Common_Rust: 100%|███████████████████████████████████████████████████| 1306/1306 [00:25<00:00, 52.02it/s]
# 📁 Processing Cotton Aphid: 100%|██████████████████████████████████████████████████████| 39/39 [00:01<00:00, 25.84it/s]
# 📁 Processing cotton mealy bug: 100%|██████████████████████████████████████████████████| 93/93 [00:03<00:00, 25.80it/s]
# 📁 Processing cotton whitefly: 100%|███████████████████████████████████████████████████| 55/55 [00:02<00:00, 22.45it/s]
# 📁 Processing Flag Smut: 100%|███████████████████████████████████████████████████████| 179/179 [00:03<00:00, 57.17it/s]
# 📁 Processing Gray_Leaf_Spot: 100%|██████████████████████████████████████████████████| 574/574 [00:10<00:00, 53.59it/s]
# 📁 Processing Healthy cotton: 100%|██████████████████████████████████████████████████| 426/426 [00:08<00:00, 50.05it/s]
# 📁 Processing Healthy Maize: 100%|█████████████████████████████████████████████████| 1162/1162 [00:17<00:00, 67.64it/s]
# 📁 Processing Healthy Wheat: 100%|███████████████████████████████████████████████████| 181/181 [00:36<00:00,  4.98it/s]
# 📁 Processing Leaf Curl: 100%|███████████████████████████████████████████████████████| 418/418 [00:08<00:00, 49.33it/s]
# 📁 Processing Leaf smut: 100%|█████████████████████████████████████████████████████████| 40/40 [00:02<00:00, 18.09it/s]
# 📁 Processing maize ear rot: 100%|███████████████████████████████████████████████████| 115/115 [00:06<00:00, 18.10it/s]
# 📁 Processing maize fall armyworm: 100%|█████████████████████████████████████████████| 108/108 [00:07<00:00, 14.84it/s]
# 📁 Processing maize stem borer:  83%|█████████████████████████████████████████▌        | 79/95 [00:03<00:00, 23.12it/s]C:\Users\tiwar\anaconda3\Lib\site-packages\PIL\Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 📁 Processing maize stem borer: 100%|██████████████████████████████████████████████████| 95/95 [00:05<00:00, 18.84it/s]
# 📁 Processing Mosaic sugarcane: 100%|████████████████████████████████████████████████| 462/462 [00:17<00:00, 26.17it/s]
# 📁 Processing pink bollworm in cotton: 100%|███████████████████████████████████████████| 29/29 [00:00<00:00, 32.58it/s]
# 📁 Processing red cotton bug: 100%|████████████████████████████████████████████████████| 69/69 [00:02<00:00, 25.35it/s]
# 📁 Processing RedRot sugarcane: 100%|████████████████████████████████████████████████| 592/592 [00:18<00:00, 32.58it/s]
# 📁 Processing RedRust sugarcane: 100%|█████████████████████████████████████████████████| 75/75 [00:01<00:00, 66.67it/s]
# 📁 Processing Rice Blast: 100%|████████████████████████████████████████████████████| 1440/1440 [00:23<00:00, 62.03it/s]
# 📁 Processing Sugarcane Healthy: 100%|███████████████████████████████████████████████| 522/522 [00:18<00:00, 28.07it/s]
# 📁 Processing thirps on  cotton: 100%|█████████████████████████████████████████████████| 36/36 [00:00<00:00, 37.66it/s]
# 📁 Processing Tungro: 100%|████████████████████████████████████████████████████████| 1308/1308 [00:23<00:00, 55.05it/s]
# 📁 Processing Wheat aphid: 100%|█████████████████████████████████████████████████████| 156/156 [00:02<00:00, 53.97it/s]
# 📁 Processing Wheat black rust: 100%|████████████████████████████████████████████████| 161/161 [00:45<00:00,  3.54it/s]
# 📁 Processing Wheat Brown leaf Rust: 100%|█████████████████████████████████████████████| 90/90 [00:01<00:00, 54.38it/s]
# 📁 Processing Wheat leaf blight: 100%|███████████████████████████████████████████████| 143/143 [00:15<00:00,  9.00it/s]
# 📁 Processing Wheat mite: 100%|██████████████████████████████████████████████████████| 154/154 [00:03<00:00, 46.41it/s]
# 📁 Processing Wheat powdery mildew: 100%|████████████████████████████████████████████| 169/169 [00:03<00:00, 46.38it/s]
# 📁 Processing Wheat scab: 100%|████████████████████████████████████████████████████████| 95/95 [00:01<00:00, 68.65it/s]
# 📁 Processing Wheat Stem fly: 100%|██████████████████████████████████████████████████| 172/172 [00:03<00:00, 51.35it/s]
# 📁 Processing Wheat___Yellow_Rust: 100%|███████████████████████████████████████████████| 92/92 [00:01<00:00, 63.73it/s]
# 📁 Processing Wilt: 100%|████████████████████████████████████████████████████████████| 419/419 [00:08<00:00, 48.18it/s]
# 📁 Processing Yellow Rust Sugarcane: 100%|███████████████████████████████████████████| 505/505 [00:17<00:00, 29.04it/s]
# ✅ Done: 15341 images saved.
# ⚠️ Corrupted/Skipped: 1
#
# 🔄 Processing Dataset: wheat_disease
# 📁 Processing Aphid: 100%|███████████████████████████████████████████████████████████| 903/903 [00:17<00:00, 50.39it/s]
# 📁 Processing Black Rust: 100%|██████████████████████████████████████████████████████| 576/576 [01:59<00:00,  4.82it/s]
# 📁 Processing Blast: 100%|███████████████████████████████████████████████████████████| 647/647 [00:35<00:00, 18.31it/s]
# 📁 Processing Brown Rust: 100%|████████████████████████████████████████████████████| 1271/1271 [02:05<00:00, 10.17it/s]
# 📁 Processing Common Root Rot: 100%|█████████████████████████████████████████████████| 614/614 [00:14<00:00, 41.47it/s]
# 📁 Processing Fusarium Head Blight: 100%|████████████████████████████████████████████| 611/611 [00:10<00:00, 57.06it/s]
# 📁 Processing Healthy: 100%|███████████████████████████████████████████████████████| 1000/1000 [01:34<00:00, 10.53it/s]
# 📁 Processing Leaf Blight: 100%|█████████████████████████████████████████████████████| 842/842 [00:34<00:00, 24.16it/s]
# 📁 Processing Mildew: 100%|████████████████████████████████████████████████████████| 1081/1081 [00:28<00:00, 37.89it/s]
# 📁 Processing Mite: 100%|████████████████████████████████████████████████████████████| 800/800 [00:17<00:00, 45.38it/s]
# 📁 Processing Septoria: 100%|██████████████████████████████████████████████████████| 1144/1144 [00:56<00:00, 20.43it/s]
# 📁 Processing Smut: 100%|██████████████████████████████████████████████████████████| 1310/1310 [00:25<00:00, 51.20it/s]
# 📁 Processing Stem fly: 100%|████████████████████████████████████████████████████████| 234/234 [00:04<00:00, 49.20it/s]
# 📁 Processing Tan spot: 100%|████████████████████████████████████████████████████████| 770/770 [00:21<00:00, 35.01it/s]
# 📁 Processing Yellow Rust: 100%|███████████████████████████████████████████████████| 1301/1301 [00:23<00:00, 55.97it/s]
# ✅ Done: 13104 images saved.
# ⚠️ Corrupted/Skipped: 0

# %%
def count_processed_images(processed_dir):
    total = 0
    class_wise = {}

    for cls in os.listdir(processed_dir):
        cls_path = os.path.join(processed_dir, cls)
        if os.path.isdir(cls_path):
            count = len(os.listdir(cls_path))
            class_wise[cls] = count
            total += count

    print("📊 Image count per class:\n")
    for k, v in class_wise.items():
        print(f"🟢 {k}: {v} images")
    
    print(f"\n✅ TOTAL IMAGES: {total}")

# ✅ Run this
count_processed_images(processed_path)
# Out:
# 📊 Image count per class:
#
# 🟢 American Bollworm on Cotton: 56 images
# 🟢 Anthracnose on Cotton: 29 images
# 🟢 Aphid: 903 images
# 🟢 Apple_leaf: 88 images
# 🟢 Apple_rust_leaf: 106 images
# 🟢 Apple_Scab_Leaf: 93 images
# 🟢 Army worm: 40 images
# 🟢 bacterial_blight in Cotton: 489 images
# 🟢 Becterial Blight in Rice: 1584 images
# 🟢 Bell_pepper_leaf: 42 images
# 🟢 Bell_pepper_leaf_spot: 83 images
# 🟢 Black Rust: 576 images
# 🟢 Blast: 647 images
# 🟢 Blueberry_leaf: 117 images
# 🟢 bollrot on Cotton: 2 images
# 🟢 bollworm on Cotton: 22 images
# 🟢 Brown Rust: 1271 images
# 🟢 Brownspot: 1640 images
# 🟢 Cherry_leaf: 57 images
# 🟢 Common Root Rot: 614 images
# 🟢 Common_Rust: 1306 images
# 🟢 Corn_Gray_leaf_spot: 67 images
# 🟢 Corn_leaf_blight: 194 images
# 🟢 Corn_rust_leaf: 117 images
# 🟢 Cotton Aphid: 39 images
# 🟢 cotton mealy bug: 93 images
# 🟢 cotton whitefly: 55 images
# 🟢 Flag Smut: 179 images
# 🟢 Fusarium Head Blight: 611 images
# 🟢 grape_leaf: 75 images
# 🟢 grape_leaf_black_rot: 79 images
# 🟢 Gray_Leaf_Spot: 574 images
# 🟢 Healthy: 1000 images
# 🟢 Healthy cotton: 426 images
# 🟢 Healthy Maize: 1162 images
# 🟢 Healthy Wheat: 180 images
# 🟢 Leaf Blight: 842 images
# 🟢 Leaf Curl: 418 images
# 🟢 Leaf smut: 40 images
# 🟢 maize ear rot: 115 images
# 🟢 maize fall armyworm: 108 images
# 🟢 maize stem borer: 95 images
# 🟢 Mildew: 1081 images
# 🟢 Mite: 800 images
# 🟢 Mosaic sugarcane: 462 images
# 🟢 Peach_leaf: 112 images
# 🟢 pink bollworm in cotton: 29 images
# 🟢 Potato_leaf_early_blight: 171 images
# 🟢 Potato_leaf_late_blight: 208 images
# 🟢 Raspberry_leaf: 119 images
# 🟢 red cotton bug: 69 images
# 🟢 RedRot sugarcane: 592 images
# 🟢 RedRust sugarcane: 75 images
# 🟢 Rice Blast: 1440 images
# 🟢 Septoria: 1144 images
# 🟢 Smut: 1310 images
# 🟢 Soyabean_leaf: 65 images
# 🟢 Squash_Powdery_mildew_leaf: 130 images
# 🟢 Stem fly: 234 images
# 🟢 Strawberry_leaf: 96 images
# 🟢 Sugarcane Healthy: 522 images
# 🟢 Tan spot: 770 images
# 🟢 thirps on  cotton: 36 images
# 🟢 Tomato_Early_blight_leaf: 88 images
# 🟢 Tomato_leaf: 52 images
# 🟢 Tomato_leaf_bacterial_spot: 110 images
# 🟢 Tomato_leaf_late_blight: 111 images
# 🟢 Tomato_leaf_mosaic_virus: 54 images
# 🟢 Tomato_leaf_yellow_virus: 238 images
# 🟢 Tomato_mold_leaf: 91 images
# 🟢 Tomato_Septoria_leaf_spot: 157 images
# 🟢 Tomato_two_spotted_spider_mites_leaf: 2 images
# 🟢 Tungro: 1308 images
# 🟢 Wheat aphid: 156 images
# 🟢 Wheat black rust: 161 images
# 🟢 Wheat Brown leaf Rust: 90 images
# 🟢 Wheat leaf blight: 143 images
# 🟢 Wheat mite: 154 images
# 🟢 Wheat powdery mildew: 169 images
# 🟢 Wheat scab: 95 images
# 🟢 Wheat Stem fly: 172 images
# 🟢 Wheat___Yellow_Rust: 92 images
# 🟢 Wilt: 419 images
# 🟢 Yellow Rust: 1301 images
# 🟢 Yellow Rust Sugarcane: 505 images
#
# ✅ TOTAL IMAGES: 31367
